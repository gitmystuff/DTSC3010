# %% [markdown]
# <a href="https://colab.research.google.com/github/gitmystuff/DTSC3010/blob/main/Week_12/Data_Science_Fiction_III.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science Fiction III

# %% [markdown]
# ## Getting Started
#
# * Colab - get notebook from gitmystuff DTSC3010 repository
# * Save a Copy in Drive
# * Remove Copy of
# * Edit name
# * Clean up Colab Notebooks folder
# * Submit shared link

# %% [markdown]
# ## Instructions
#
# The goal of this assignment is to take messy data, clean it up, and then analyze it using logistic regression.
#
# * Run Parts 1 and 2 being careful to take in what's going on
# * In Part 3 you are asked to clean the data in preparation for modeling
# * Part 4 - perform necessary feature engineering
# * Part 5 - select the variables that will be more useful for classification
# * Part 6 - model the data and evaluate, explain concepts when asked

# %% [markdown]
# # Part 1 - The Data

# %% [markdown]
# ## Seed the Project

# %%
import time
import numpy as np
import random

def generate_user_seed():
    # Get current time in nanoseconds (more granular)
    nanoseconds = time.time_ns()

    # Add a small random component to further reduce collision chances
    random_component = random.randint(0, 1000)  # Adjust range as needed

    # Combine them (XOR is a good way to mix values)
    seed = nanoseconds ^ random_component

    # Ensure the seed is within the valid range for numpy's seed
    seed = seed % (2**32)  # Modulo to keep it within 32-bit range

    return seed

user_seed = generate_user_seed()
print(user_seed)
random_state = np.random.seed(user_seed)
# Out:
# 3637044556

# %% [markdown]
# ## Faker

# %%
pip install Faker -q

# %%
fifty_labels = [f"label_{i}" for i in range(1, 51)]

# %%
# create demographic data
import numpy as np
import pandas as pd
from faker import Faker
fake = Faker()

n = 1000

output = []
for x in range(n):
    biology = np.random.choice(['Cytophore', 'Kymete'], p=[0.5, 0.5])
    output.append({
        'categorical_1': biology,
        'categorical_2': np.random.choice(['Xylosian', 'Veridian', 'Thalassian']),
        'name_1': fake.first_name_female() if biology == 'Cytophore' else fake.first_name_male(),
        'name_2': fake.last_name(),
        'code': fake.zipcode(),
        'date': fake.date_of_birth(),
        'location': np.random.choice(fifty_labels)
    })

demographics = pd.DataFrame(output)
print(demographics.shape)
demographics.head()
# Out:
# (1000, 7)
#   categorical_1 categorical_2    name_1    name_2   code        date  location
# 0     Cytophore      Veridian       Ann    Atkins  58807  1956-03-13  label_23
# 1     Cytophore      Xylosian     Renee   Carroll  32691  1974-01-02  label_25
# 2     Cytophore      Veridian     Amber    Taylor  54872  1918-01-12  label_30
# 3     Cytophore    Thalassian   Rebecca  Lawrence  77020  1938-12-09  label_33
# 4     Cytophore      Veridian  Samantha     Ramos  08480  1965-06-26  label_20

# %% [markdown]
# **Cytophore**
#
# * **Root Meaning:** "Cell-bearer" (Greek *cyto* = cell + *phore* = carrier).
# * **Physical Vibe:** Solid, structured, and modular.
# * **Concept:** Represents a demographic with a rigid, vessel-like biological makeup.
#
# **Kymete**
#
# * **Root Meaning:** "Wave-form" (Greek *kyma* = wave/flowing).
# * **Physical Vibe:** Fluid, adaptive, and resonant.
# * **Concept:** Represents a demographic with a flowing, less rigid biological makeup.
#
# **Veridian**
#
# * **Root Meaning:** "Green" (Latin *viridis*).
# * **Theme:** Flora and lush nature.
# * **Concept:** A group tied to forest-like environments or plant-based growth.
#
# **Xylosian**
#
# * **Root Meaning:** "Woody" (Greek *xylon* = wood).
# * **Theme:** Trees and timber.
# * **Concept:** A group tied to arboreal (tree-dwelling) or hardened, bark-like structures.
#
# **Thalassian**
#
# * **Root Meaning:** "Of the sea" (Greek *thalassa* = sea).
# * **Theme:** Water and oceans.
# * **Concept:** A group tied to aquatic or deep-sea environments.

# %% [markdown]
# In biological and sci-fi contexts, a **Cytophore** is essentially a "cell-carrier"—a specialized structure or organism designed to house, transport, or support other cells.
#
# **Real-World Biological Examples**
#
# * **Siphonophores (e.g., Portuguese Man o' War):** These are not single animals, but colonies of specialized individuals called zooids. The central "stem" or specialized parts that carry these zooids act as a cytophore, providing the framework for the rest of the colony to live on.
# * **Fertilization Structures:** In some microscopic fungi and mosses, a cytophore is the stalk-like structure that supports or carries reproductive cells (gametes) to ensure they are positioned correctly for dispersal.
# * **Specialized Tissues:** In complex organisms, certain "scaffold" cells (like glial cells in the brain) act as carriers and support systems for more specialized cells (like neurons), effectively serving a cytophoric function.
#
# **Sci-Fi / Conceptual Examples**
#
# * **Modular "Hive" Beings:** A creature that is made of a rigid, honeycomb-like exterior that carries its vital "brain cells" in protected internal pockets.
# * **Crystalline Organisms:** Beings that grow in geometric, solid shapes. Their physical body is a literal "vessel" (Cyto) that carries (Phore) their consciousness or energy in a solid state.
# * **Living Seed-Pods:** A demographic that resembles a walking plant-husk or shell, where the "person" is actually a collection of thousands of smaller cells working together inside a hard, bark-like carrier.
#
# ---
#
# In contrast to the structured, vessel-like nature of a Cytophore, a **Kymete** (from the Greek *kyma*, meaning "wave") is defined by fluidity, movement, and a lack of rigid boundaries.
#
# **Real-World Biological Examples**
#
# * **Slime Molds (*Physarum polycephalum*):** These are single-celled organisms that move like a slow-motion wave. They don't have a fixed shape; they flow toward food sources in a pulsing, rhythmic "shuttle flow."
# * **Jellyfish and Pelagic Tunicates:** These creatures are primarily water-based. Their bodies are "resonant"—they move by pulsing their entire form in waves to navigate the ocean.
# * **Cytoplasmic Streaming:** Inside many plant and animal cells, the internal fluids (cytoplasm) move in a constant, circular "wave" to transport nutrients. A Kymete is essentially this internal fluid motion turned into an entire organism.
#
# **Sci-Fi / Conceptual Examples**
#
# * **Amorphous Beings:** Entities that change shape at will, resembling a pool of mercury or a thick liquid. They don't have "limbs" so much as they have "waves of pressure" that allow them to move.
# * **Bio-Acoustic Organisms:** Creatures that exist as a physical vibration. Their "body" is a collection of semi-solid particles held together by a constant sound frequency or standing wave.
# * **Bioluminescent Clouds:** A demographic that looks like a glowing mist or a school of tiny particles. They travel through the air in undulating patterns, much like a starling murmuration or a wave in the sea.
#
# **Summary Comparison for your Data**
#
# | Feature | **Cytophore** | **Kymete** |
# | :--- | :--- | :--- |
# | **Physical State** | Solid / Modular | Fluid / Undulating |
# | **Boundaries** | Fixed (Vessel) | Shifting (Wave) |
# | **Movement** | Mechanical / Articulated | Pulsing / Flowing |
# | **Analogy** | A ship carrying a crew | The current of the river itself |
#
# * **Cytophore:** Think **Exoskeleton**. It has clear borders, a defined shape, and looks like a "container" for life.
# * **Kymete:** Think **Endoskeleton or Jellyfish**. It is wavy, translucent, and looks like "flowing" life.

# %% [markdown]
# ## Create Independent Variable Correlated with Class

# %%
import numpy as np
import pandas as pd

def generate_feature(df, class_col, coeff, intercept):
    """
    Generates normally distributed feature data for a logistic regression model.

    Args:
        df: The pandas DataFrame containing the class column.
        class_col: The name of the class column (containing 0s and 1s).
        coeff: The coefficient for the feature in the logistic regression model.
        intercept: The intercept of the logistic regression model.

    Returns:
        A pandas Series containing the generated feature data.
    """

    # Generate probabilities based on the class
    probs = np.random.rand(len(df))  # Initial random probabilities
    probs = np.where(df[class_col] == 1, probs * 0.8 + 0.2, probs * 0.8)  # Adjust for class

    # Apply the inverse logit (logit) function
    logits = np.log(probs / (1 - probs))

    # Calculate the feature values
    feature_values = (logits - intercept) / coeff

    return pd.Series(feature_values)

# %% [markdown]
# ## Make Classification

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression

def make_linear_y(row):
  model = LogisticRegression()
  model.fit(X, y)
  coefficients = model.coef_
  intercept = model.intercept_
  f_of_x = intercept + coefficients[0][0]*row['informative_1'] + coefficients[0][1]*row['informative_2']
  # print(f_of_x[0])
  return f_of_x[0]

# Adjust the make_classification parameters:
# Set n_informative and n_redundant to values that sum to less than n_features
X, y = make_classification(n_samples=n, n_features=2, n_informative=2, n_redundant=0, n_repeated=0, random_state=42)
df = pd.DataFrame(X, columns=['informative_1', 'informative_2'])
df = pd.concat([demographics, df], axis=1).reset_index(drop=True)

df['target'] = df.apply(make_linear_y, axis=1) # the dependent variable for linear regression
df['class'] = y # the dependent variable for classification
df['corr_feature_class'] = generate_feature(df, 'class', 0.5, -1)
df.head()
# Out:
#   categorical_1 categorical_2    name_1    name_2   code        date  \
# 0     Cytophore      Veridian       Ann    Atkins  58807  1956-03-13
# 1     Cytophore      Xylosian     Renee   Carroll  32691  1974-01-02
# 2     Cytophore      Veridian     Amber    Taylor  54872  1918-01-12
# 3     Cytophore    Thalassian   Rebecca  Lawrence  77020  1938-12-09
# 4     Cytophore      Veridian  Samantha     Ramos  08480  1965-06-26
#
#    location  informative_1  informative_2    target  class  corr_feature_class
# 0  label_23      -0.999102      -0.663860 -0.904224      1            2.872820
# 1  label_25       1.246686       1.153597  2.324370      1           -0.586568
# 2  label_30       0.962777       0.859397  1.778217      1            2.998593
# 3  label_33      -2.957441       2.033645  5.451235      1            0.211591
# 4  label_20       1.141165       1.059449  2.153926      1            8.846901

# %% [markdown]
# ## Automation Functions
#
# 1. gen_null(series, perc)
# 2. gen_quasi_constants(primary_label, variation_percentage=.2, replace=False)
# 3. gen_normal_data(mu=0, std=1, size=len(df))
# 4. gen_uniform_data(size=len(df))
# 5. gen_multivariate_normal_data(mean=[0, 0], cov=[[1, 0], [0, 1]], size=len(df))
# 6. gen_correlated_normal_series(original_series, target_correlation, size=len(df))
# 7. gen_correlated_uniform_series(original_series, correlation_coefficient=0, size=len(df))
# 8. gen_outliers(mean=0, std_dev=1, size=len(df), outlier_percentage=0.1, outlier_magnitude=3)
# 9. gen_standard_scaling(mean=50, std_dev=10, size=len(df), scale_factor=1000)
# 10. gen_minmax_scaling(mean=50, std_dev=10, size=len(df), range_factor=10)
# 11. random_choice_data(choices, size)

# %%
# functions
import pandas as pd
import numpy as np
from scipy.stats import norm
from scipy.optimize import minimize


def gen_null(series, perc):
  """
  Introduces null values (np.nan) into a list based on a specified percentage.

  Args:
      var: The variable to modify.
      perc: The percentage of values to replace with nulls (0-100).

  Returns:
      The modified variable with null.
  """
  var = series.copy()
  num_nulls = int(len(var) * (perc / 100))
  indices_to_replace = np.random.choice(len(var), num_nulls, replace=False)

  for idx in indices_to_replace:
      var[idx] = np.nan

  return var

def gen_quasi_constants(primary_label, variation_percentage=.2, size=len(df)):
  """
  Generates quasi-constant labels for a Series, with a small percentage of variation.

  Args:
      primary_label: The main label to use for most values.
      variation_percentage: The percentage of labels to vary (0-100).

  Returns:
      A new Series containing the quasi-constant labels.
  """

  series = pd.Series(np.full(size, primary_label))
  num_variations = int(size * (variation_percentage / 100))
  variation_indices = np.random.choice(series.index, num_variations, replace=False)
  primary_label = primary_label + '_0'
  variation1 = primary_label + '_1'
  variation2 = primary_label + '_2'

  labels = pd.Series([primary_label] * len(series), index=series.index)
  labels.loc[variation_indices] = np.random.choice([variation1, variation2], size=num_variations)  # Adjust variations as needed

  return labels

def gen_normal_data(mu=0, std=1, size=len(df)):
  """
  Generates a normal dataset given the mean and standard deviation

  Args:
        mu: The mean of the normal distribution.
        std: The standard deviation of the normal distribution.
        size: The number of data points to generate.

  Returns:
        A normally distributed series.
  """
  return np.random.normal(mu, std, size)

def gen_uniform_data(size=len(df)):
  """
  Generates a uniform dataset

  Args:
        size: The number of data points to generate.

  Returns:
        A uniform distributed series.
  """
  return np.random.uniform(size=size)

def gen_multivariate_normal_data(mean=[0, 0], cov=[[1, 0], [0, 1]], size=len(df)):
  """
  Generates two datasets with a multivariate normal distribution given the mean and covariance matrix

  Args:
        mean: The mean of each of the datasets.
        cov: The covariance matrix of the datasets.
        size: The number of data points to generate.

  Returns:
        Two correlated series.
  """
  ds1, ds2 = np.random.multivariate_normal(mean, cov, size, tol=1e-6).T # ds = dataset
  return ds1, ds2

def gen_correlated_normal_series(original_series, target_correlation, size=len(df)):
  """
  Generates a correlated series based on a given series.

  This function takes an original series as input and generates a new series
  that is correlated with the original series. The correlation between the
  original and generated series is approximately equal to the specified
  target correlation.

  The generated series is created by linearly transforming the original series
  and adding Gaussian noise with an adjusted standard deviation to achieve the
  desired correlation.

  Args:
      original_series (numpy.ndarray): The original series.
      target_correlation (float): The desired Pearson correlation coefficient
          between the original and generated series.

  Returns:
      numpy.ndarray: The generated correlated series.
  """
  return np.mean(original_series) + target_correlation * (original_series - np.mean(original_series)) \
  +  np.random.normal(0, np.sqrt(1 - target_correlation**2) * np.std(original_series), len(original_series))
  """
  Explanation

  This one-liner leverages the properties of linear transformations and normal distributions to generate a correlated series.

  It first centers the original_series by subtracting its mean.
  It then scales this centered series by the target_correlation.
  Finally, it adds Gaussian noise with a standard deviation adjusted to ensure the overall correlation matches the target_correlation.
  """

def gen_correlated_uniform_series(original_series, correlation_coefficient=0, size=len(df)):
  """
  Work in progress

  Generates a new series correlated with the given series based on the specified correlation coefficient,
  using rank correlation to ensure the generated series follows a uniform distribution.

  Args:
      original_series (numpy.ndarray or list): The original series.
      correlation_coefficient (float): The desired correlation coefficient between the original and generated series.
      size: The number of data points to generate.

  Returns:
      The generated correlated series with a uniform distribution.
  """
  z_scores = (original_series - np.mean(original_series)) / np.std(original_series)
  correlation_coefficient=.7
  return norm.cdf(correlation_coefficient * norm.ppf(np.random.uniform(size=size)) + np.sqrt(1 - correlation_coefficient**2) * z_scores)

def pearson_r_func(x, y, y_mean, y_std, desired_r):
    x_mean = np.mean(x)
    x_std = np.std(x)
    numerator = np.sum((x - x_mean) * (y - y_mean))
    denominator = x_std * y_std * len(x)
    calculated_r = numerator / denominator
    return (calculated_r - desired_r)**2  # Minimize the squared difference

def minimize_r(original_series, target_correlation, size=len(df)):
    y = original_series
    y_mean = np.mean(y)
    y_std = np.std(y)
    desired_r = target_correlation

    # Initial guess for x values
    x0 = np.random.uniform(size=len(original_series))

    # Solve for x
    result = minimize(pearson_r_func, x0, args=(y, y_mean, y_std, desired_r))

    if result.success:
        x_solution = result.x
        # print("Solution for x:", x_solution)
        return x_solution
    else:
        print("Optimization failed.")

def gen_outliers(mean=0, std_dev=1, size=len(df), outlier_percentage=0.1, outlier_magnitude=3):
    """
    Generates a normal distribution with outliers.

    Args:
        mean (float): The mean of the normal distribution.
        std_dev (float): The standard deviation of the normal distribution.
        size (int): The number of samples to generate.
        outlier_percentage (float): The percentage of outliers to introduce (between 0 and 1).
        outlier_magnitude (float): The magnitude by which outliers deviate from the mean.

    Returns:
        numpy.ndarray: The generated data with outliers.
    """
    data = np.random.normal(mean, std_dev, size)
    num_outliers = int(size * outlier_percentage)
    outlier_indices = np.random.choice(size, num_outliers, replace=False)
    for index in outlier_indices:
        if np.random.rand() < 0.5:
            data[index] += outlier_magnitude
        else:
            data[index] -= outlier_magnitude

    return data

def gen_standard_scaling(mean=50, std_dev=10, size=len(df), scale_factor=1000):
  """
  Generates data with a specified mean and standard deviation, then scales it by a factor to create a distribution needing scaling.

  Args:
      mean (float): The mean of the original distribution.
      std_dev (float): The standard deviation of the original distribution.
      size (int): The number of samples to generate.
      scale_factor (float): The factor by which to scale the original distribution.

  Returns:
      numpy.ndarray: The generated data needing scaling.
  """
  original_data = np.random.normal(mean, std_dev, size)
  return original_data * scale_factor

def gen_minmax_scaling(mean=50, std_dev=10, size=len(df), range_factor=10):
  """
  Generates data with a specified mean and standard deviation, then scales and shifts it to create a distribution needing MinMax scaling.

  Args:
      mean (float): The mean of the original distribution.
      std_dev (float): The standard deviation of the original distribution.
      size (int): The number of samples to generate.
      range_factor (float): The factor to expand the range of the original distribution.

  Returns:
      numpy.ndarray: The generated data needing scaling.
  """

  # Generate the original data
  original_data = np.random.normal(mean, std_dev, size)

  # Expand the range of the data
  min_val = np.min(original_data)
  max_val = np.max(original_data)
  return (original_data - min_val) * range_factor + min_val

def random_choice_data(choices, size):
  """
  Generates a new series correlated with the given series based on the specified correlation coefficient,
  using rank correlation to ensure the generated series follows a uniform distribution.

  Args:
      original_series (numpy.ndarray or list): The original series.
      correlation_coefficient (float): The desired correlation coefficient between the original and generated series.

  Returns:
      numpy.ndarray: The generated correlated series with a uniform distribution.
  """
  return np.random.choice(choices, size=size)

# %%
# categorical variables with little correlation to target
df['random choice 2'] = random_choice_data(['Rand Choice 1', 'Rand Choice 2'], size=len(df))
df['random choice 4'] = random_choice_data(['North', 'South', 'East', 'West'], size=len(df))
df['random choice 7'] = random_choice_data(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'], size=len(df))

# categorical random choices with random # of labels
num_labels = np.random.randint(3, 5)
df[f'random label num {num_labels}'] = random_choice_data([f'label num lo {i}' for i in range(1, num_labels + 1)], size=len(df))

num_labels = np.random.randint(10, 15)
df[f'random label num {num_labels}'] = random_choice_data([f'label num hi {i}' for i in range(1, num_labels + 1)], size=len(df))

# %%
# categorical variables correlated with target
df['pd qcut1'] = pd.qcut(df['target'], 2, labels=['Low', 'High']) # bi label
df['pd qcut2'] = pd.qcut(df['target'], 4, labels=['Q1', 'Q2', 'Q3', 'Q4']) # 4 labels

quantiles = [0, 0.1, 0.2, 0.4, 0.6, 0.8, 1]
df['pd qcut3'] = pd.qcut(df['target'], quantiles, labels=['G1', 'G2', 'G3', 'G4', 'G5', 'G6']) # 6 labels

# %%
# generate four numerical normally distributed continuous features that have a correlation greater than absolute value of .5 with each other
# gen_multivariate_normal_data(mean=[0, 0], cov=[[1, 0], [0, 1]], size=len(df))
df['multicollinearity 1'], df['multicollinearity 2'] = gen_multivariate_normal_data(mean=[0, 0], cov=[[1, .7], [.7, 1]], size=len(df))
df['multicollinearity 3'], df['multicollinearity 4'] = gen_multivariate_normal_data(mean=[0, 0], cov=[[1, .9], [.9, 1]], size=len(df))

# %%
# generate two normally distributed features that are correlated with the target
# gen_correlated_normal_series(original_series, target_correlation, size=len(df))
df['correlated w target 1'] = gen_correlated_normal_series(df['target'], target_correlation=.5)
df['correlated w target 2'] = gen_correlated_normal_series(df['target'], target_correlation=.7)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   categorical_1          1000 non-null   object
#  1   categorical_2          1000 non-null   object
#  2   name_1                 1000 non-null   object
#  3   name_2                 1000 non-null   object
#  4   code                   1000 non-null   object
#  5   date                   1000 non-null   object
#  6   location               1000 non-null   object
#  7   informative_1          1000 non-null   float64
#  8   informative_2          1000 non-null   float64
#  9   target                 1000 non-null   float64
#  10  class                  1000 non-null   int64
#  11  corr_feature_class     1000 non-null   float64
#  12  random choice 2        1000 non-null   object
#  13  random choice 4        1000 non-null   object
#  14  random choice 7        1000 non-null   object
#  15  random label num 4     1000 non-null   object
#  16  random label num 10    1000 non-null   object
#  17  pd qcut1               1000 non-null   category
#  18  pd qcut2               1000 non-null   category
#  19  pd qcut3               1000 non-null   category
#  20  multicollinearity 1    1000 non-null   float64
#  21  multicollinearity 2    1000 non-null   float64
#  22  multicollinearity 3    1000 non-null   float64
#  23  multicollinearity 4    1000 non-null   float64
#  24  correlated w target 1  1000 non-null   float64
#  25  correlated w target 2  1000 non-null   float64
# dtypes: category(3), float64(10), int64(1), object(12)
# memory usage: 183.3+ KB

# %%
# generate two uniformly distributed features that are correlated with the target
# gen_correlated_uniform_series(original_series, correlation_coefficient=0, size=len(df))
df['uniform corr 1'] = gen_correlated_uniform_series(df['target'])
df['uniform corr 2'] = gen_correlated_uniform_series(df['target'])

# %%
# create two features that are duplicates of other features
df['duplicate_1'] = df['informative_1']
df['duplicate_2'] = df['informative_2']

# %%
# create two numerical features with outliers
df['outliers 1'] = gen_outliers(mean=0, std_dev=1, size=len(df), outlier_percentage=0.1, outlier_magnitude=3)
df['outliers 2'] = gen_outliers(mean=3, std_dev=2, size=len(df), outlier_percentage=0.2, outlier_magnitude=2)

# %%
# create a numerical feature that needs standard scaling
df['standard scaling'] = gen_standard_scaling()

# %%
# create a numerical feature that needs min max scaling
df['min max scaling'] = gen_minmax_scaling()

# %%
# generate null values
for col in df.drop(['class', 'informative_1', 'informative_2', 'target', 'duplicate_1', 'duplicate_2'], axis=1).columns:
    df[col] = gen_null(df[col], np.random.choice([0, 5, 10, 20, 30, 50], size=1).item())

# %%
# create two features that have constant values
df['constant_1'] = 'constant_value'
df['constant_2'] = 'constant_value'

# %%
# create two features with semi constant values
df['semi_constant_1'] = gen_quasi_constants('q_const', variation_percentage = 1)
df['semi_constant_2'] = gen_quasi_constants('q_const', variation_percentage = 1)

# %%
print(df.info())  # check progress
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   categorical_1          700 non-null    object
#  1   categorical_2          950 non-null    object
#  2   name_1                 700 non-null    object
#  3   name_2                 1000 non-null   object
#  4   code                   700 non-null    object
#  5   date                   800 non-null    object
#  6   location               800 non-null    object
#  7   informative_1          1000 non-null   float64
#  8   informative_2          1000 non-null   float64
#  9   target                 1000 non-null   float64
#  10  class                  1000 non-null   int64
#  11  corr_feature_class     950 non-null    float64
#  12  random choice 2        900 non-null    object
#  13  random choice 4        700 non-null    object
#  14  random choice 7        1000 non-null   object
#  15  random label num 4     700 non-null    object
#  16  random label num 10    950 non-null    object
#  17  pd qcut1               1000 non-null   category
#  18  pd qcut2               500 non-null    category
#  19  pd qcut3               500 non-null    category
#  20  multicollinearity 1    500 non-null    float64
#  21  multicollinearity 2    900 non-null    float64
#  22  multicollinearity 3    1000 non-null   float64
#  23  multicollinearity 4    500 non-null    float64
#  24  correlated w target 1  950 non-null    float64
#  25  correlated w target 2  800 non-null    float64
#  26  uniform corr 1         900 non-null    float64
#  27  uniform corr 2         800 non-null    float64
#  28  duplicate_1            1000 non-null   float64
#  29  duplicate_2            1000 non-null   float64
#  30  outliers 1             800 non-null    float64
#  31  outliers 2             700 non-null    float64
#  32  standard scaling       800 non-null    float64
#  33  min max scaling        800 non-null    float64
#  34  constant_1             1000 non-null   object
#  35  constant_2             1000 non-null   object
#  36  semi_constant_1        1000 non-null   object
#  37  semi_constant_2        1000 non-null   object
# dtypes: category(3), float64(18), int64(1), object(16)
# memory usage: 277.0+ KB
# None

# %%
# add duplicates
dupes = df.loc[0:9]
df = pd.concat([df, dupes], axis=0)

# shuffle all columns
# df = df.sample(frac=1).reset_index(drop=True)
# df = df.sample(frac=1, axis=1)

# shuffle selected columns
demographic_columns = demographics.columns
remaining_columns = [col for col in df.columns if col not in demographic_columns]
# print(remaining_columns)
np.random.shuffle(remaining_columns)

# Reassemble the DataFrame with the shuffled columns
df = df[list(demographic_columns) + list(remaining_columns)]

# move target to the end of the list
class_var = 'class'
df = df[df.drop('class', axis=1).columns.tolist() + [class_var]]

print(df.shape)
print(df.info())
df.head()
# Out:
# (1010, 38)
# <class 'pandas.core.frame.DataFrame'>
# Index: 1010 entries, 0 to 9
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   categorical_1          707 non-null    object
#  1   categorical_2          960 non-null    object
#  2   name_1                 705 non-null    object
#  3   name_2                 1010 non-null   object
#  4   code                   706 non-null    object
#  5   date                   809 non-null    object
#  6   location               810 non-null    object
#  7   pd qcut2               506 non-null    category
#  8   correlated w target 1  958 non-null    float64
#  9   uniform corr 1         907 non-null    float64
#  10  standard scaling       808 non-null    float64
#  11  min max scaling        810 non-null    float64
#  12  outliers 1             810 non-null    float64
#  13  random label num 4     707 non-null    object
#  14  random choice 7        1010 non-null   object
#  15  random label num 10    960 non-null    object
#  16  semi_constant_2        1010 non-null   object
#  17  pd qcut1               1010 non-null   category
#  18  informative_2          1010 non-null   float64
#  19  multicollinearity 4    506 non-null    float64
#  20  uniform corr 2         810 non-null    float64
#  21  correlated w target 2  807 non-null    float64
#  22  multicollinearity 2    908 non-null    float64
#  23  random choice 4        708 non-null    object
#  24  duplicate_2            1010 non-null   float64
#  25  constant_1             1010 non-null   object
#  26  target                 1010 non-null   float64
#  27  informative_1          1010 non-null   float64
#  28  multicollinearity 1    508 non-null    float64
#  29  pd qcut3               506 non-null    category
#  30  semi_constant_1        1010 non-null   object
#  31  duplicate_1            1010 non-null   float64
#  32  outliers 2             709 non-null    float64
#  33  constant_2             1010 non-null   object
#  34  random choice 2        909 non-null    object
#  35  corr_feature_class     959 non-null    float64
#  36  multicollinearity 3    1010 non-null   float64
#  37  class                  1010 non-null   int64
# dtypes: category(3), float64(18), int64(1), object(16)
# memory usage: 287.6+ KB
# None
#   categorical_1 categorical_2   name_1    name_2   code        date  location  \
# 0     Cytophore      Veridian      NaN    Atkins  58807  1956-03-13  label_23
# 1     Cytophore      Xylosian    Renee   Carroll    NaN  1974-01-02  label_25
# 2           NaN      Veridian      NaN    Taylor  54872  1918-01-12  label_30
# 3           NaN    Thalassian  Rebecca  Lawrence  77020  1938-12-09  label_33
# 4     Cytophore      Veridian      NaN     Ramos    NaN         NaN  label_20
#
#   pd qcut2  correlated w target 1  uniform corr 1  ...  multicollinearity 1  \
# 0       Q2               1.840169        0.186906  ...             0.059294
# 1      NaN               1.560870        0.252188  ...             0.540519
# 2       Q3                    NaN        0.499793  ...             1.591625
# 3      NaN              -1.129332             NaN  ...                  NaN
# 4       Q3               0.073679        0.630647  ...             1.249232
#
#    pd qcut3  semi_constant_1 duplicate_1 outliers 2      constant_2  \
# 0        G4        q_const_0   -0.999102  -0.908364  constant_value
# 1        G5        q_const_0    1.246686        NaN  constant_value
# 2       NaN        q_const_0    0.962777   4.135025  constant_value
# 3        G6        q_const_0   -2.957441   2.090290  constant_value
# 4        G5        q_const_0    1.141165   3.052163  constant_value
#
#   random choice 2 corr_feature_class  multicollinearity 3  class
# 0   Rand Choice 2           2.872820             0.918553      1
# 1   Rand Choice 2          -0.586568            -1.258516      1
# 2             NaN                NaN            -0.515566      1
# 3   Rand Choice 1           0.211591            -1.030788      1
# 4   Rand Choice 2           8.846901            -0.445725      1
#
# [5 rows x 38 columns]

# %%
df.to_csv('data science fiction iii pt 1.csv', index=False)

# %% [markdown]
# # Part 2 - Exploratory Data Analysis (EDA)
#
# Exploratory data analysis (EDA) is a data analysis method that helps data scientists understand their data and identify patterns. It's often used as the first step in data analysis.

# %% [markdown]
# ## Load Data

# %%
import pandas as pd

df = pd.read_csv('data science fiction.csv')
print(df.shape)
print(df.info())
df.head()
# Out:
# (1010, 38)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   categorical_1          707 non-null    object
#  1   categorical_2          960 non-null    object
#  2   name_1                 705 non-null    object
#  3   name_2                 1010 non-null   object
#  4   code                   706 non-null    float64
#  5   date                   809 non-null    object
#  6   location               810 non-null    object
#  7   pd qcut2               506 non-null    object
#  8   correlated w target 1  958 non-null    float64
#  9   uniform corr 1         907 non-null    float64
#  10  standard scaling       808 non-null    float64
#  11  min max scaling        810 non-null    float64
#  12  outliers 1             810 non-null    float64
#  13  random label num 4     707 non-null    object
#  14  random choice 7        1010 non-null   object
#  15  random label num 10    960 non-null    object
#  16  semi_constant_2        1010 non-null   object
#  17  pd qcut1               1010 non-null   object
#  18  informative_2          1010 non-null   float64
#  19  multicollinearity 4    506 non-null    float64
#  20  uniform corr 2         810 non-null    float64
#  21  correlated w target 2  807 non-null    float64
#  22  multicollinearity 2    908 non-null    float64
#  23  random choice 4        708 non-null    object
#  24  duplicate_2            1010 non-null   float64
#  25  constant_1             1010 non-null   object
#  26  target                 1010 non-null   float64
#  27  informative_1          1010 non-null   float64
#  28  multicollinearity 1    508 non-null    float64
#  29  pd qcut3               506 non-null    object
#  30  semi_constant_1        1010 non-null   object
#  31  duplicate_1            1010 non-null   float64
#  32  outliers 2             709 non-null    float64
#  33  constant_2             1010 non-null   object
#  34  random choice 2        909 non-null    object
#  35  corr_feature_class     959 non-null    float64
#  36  multicollinearity 3    1010 non-null   float64
#  37  class                  1010 non-null   int64
# dtypes: float64(19), int64(1), object(18)
# memory usage: 300.0+ KB
# None
#   categorical_1 categorical_2   name_1    name_2     code        date  \
# 0     Cytophore      Veridian      NaN    Atkins  58807.0  1956-03-13
# 1     Cytophore      Xylosian    Renee   Carroll      NaN  1974-01-02
# 2           NaN      Veridian      NaN    Taylor  54872.0  1918-01-12
# 3           NaN    Thalassian  Rebecca  Lawrence  77020.0  1938-12-09
# 4     Cytophore      Veridian      NaN     Ramos      NaN         NaN
#
#    location pd qcut2  correlated w target 1  uniform corr 1  ...  \
# 0  label_23       Q2               1.840169        0.186906  ...
# 1  label_25      NaN               1.560870        0.252188  ...
# 2  label_30       Q3                    NaN        0.499793  ...
# 3  label_33      NaN              -1.129332             NaN  ...
# 4  label_20       Q3               0.073679        0.630647  ...
#
#    multicollinearity 1  pd qcut3  semi_constant_1 duplicate_1 outliers 2  \
# 0             0.059294        G4        q_const_0   -0.999102  -0.908364
# 1             0.540519        G5        q_const_0    1.246686        NaN
# 2             1.591625       NaN        q_const_0    0.962777   4.135025
# 3                  NaN        G6        q_const_0   -2.957441   2.090290
# 4             1.249232        G5        q_const_0    1.141165   3.052163
#
#        constant_2 random choice 2 corr_feature_class  multicollinearity 3  \
# 0  constant_value   Rand Choice 2           2.872820             0.918553
# 1  constant_value   Rand Choice 2          -0.586568            -1.258516
# 2  constant_value             NaN                NaN            -0.515566
# 3  constant_value   Rand Choice 1           0.211591            -1.030788
# 4  constant_value   Rand Choice 2           8.846901            -0.445725
#
#    class
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#
# [5 rows x 38 columns]

# %% [markdown]
# ## Var Types

# %%
df_numerical = df.select_dtypes(include='number').columns
df_object = df.select_dtypes(include=['object']).columns
df_discreet = df.select_dtypes(include=['category']).columns
df_categorical_features = df.select_dtypes(include=['category', 'object']).columns
print(df_numerical)
print(df_object)
print(df_discreet)
print(df_categorical_features)
# Out:
# Index(['code', 'correlated w target 1', 'uniform corr 1', 'standard scaling',
#        'min max scaling', 'outliers 1', 'informative_2', 'multicollinearity 4',
#        'uniform corr 2', 'correlated w target 2', 'multicollinearity 2',
#        'duplicate_2', 'target', 'informative_1', 'multicollinearity 1',
#        'duplicate_1', 'outliers 2', 'corr_feature_class',
#        'multicollinearity 3', 'class'],
#       dtype='object')
# Index(['categorical_1', 'categorical_2', 'name_1', 'name_2', 'date',
#        'location', 'pd qcut2', 'random label num 4', 'random choice 7',
#        'random label num 10', 'semi_constant_2', 'pd qcut1', 'random choice 4',
#        'constant_1', 'pd qcut3', 'semi_constant_1', 'constant_2',
#        'random choice 2'],
#       dtype='object')
# Index([], dtype='object')
# Index(['categorical_1', 'categorical_2', 'name_1', 'name_2', 'date',
#        'location', 'pd qcut2', 'random label num 4', 'random choice 7',
#        'random label num 10', 'semi_constant_2', 'pd qcut1', 'random choice 4',
#        'constant_1', 'pd qcut3', 'semi_constant_1', 'constant_2',
#        'random choice 2'],
#       dtype='object')

# %% [markdown]
# ## Correlation

# %%
# code along
df[df_numerical].corr().round(2)
# Out:
#                        code  correlated w target 1  uniform corr 1  \
# code                   1.00                  -0.03           -0.05
# correlated w target 1 -0.03                   1.00            0.31
# uniform corr 1        -0.05                   0.31            1.00
# standard scaling      -0.00                   0.01            0.07
# min max scaling        0.03                   0.01           -0.06
# outliers 1            -0.01                   0.01           -0.02
# informative_2         -0.02                   0.47            0.69
# multicollinearity 4   -0.04                   0.01            0.01
# uniform corr 2         0.04                   0.33            0.46
# correlated w target 2 -0.00                   0.32            0.53
# multicollinearity 2   -0.07                   0.06            0.02
# duplicate_2           -0.02                   0.47            0.69
# target                -0.02                   0.47            0.70
# informative_1          0.02                  -0.05           -0.03
# multicollinearity 1   -0.04                  -0.01            0.00
# duplicate_1            0.02                  -0.05           -0.03
# outliers 2             0.06                  -0.03           -0.01
# corr_feature_class    -0.03                   0.14            0.23
# multicollinearity 3   -0.06                   0.00           -0.02
# class                 -0.03                   0.33            0.55
#
#                        standard scaling  min max scaling  outliers 1  \
# code                              -0.00             0.03       -0.01
# correlated w target 1              0.01             0.01        0.01
# uniform corr 1                     0.07            -0.06       -0.02
# standard scaling                   1.00            -0.01        0.00
# min max scaling                   -0.01             1.00       -0.04
# outliers 1                         0.00            -0.04        1.00
# informative_2                      0.03             0.01        0.02
# multicollinearity 4                0.06             0.02        0.02
# uniform corr 2                     0.03             0.02       -0.00
# correlated w target 2              0.04             0.03       -0.01
# multicollinearity 2                0.04             0.06       -0.05
# duplicate_2                        0.03             0.01        0.02
# target                             0.03             0.01        0.02
# informative_1                      0.01            -0.01        0.03
# multicollinearity 1               -0.04             0.01       -0.10
# duplicate_1                        0.01            -0.01        0.03
# outliers 2                        -0.02            -0.03        0.02
# corr_feature_class                 0.01             0.01       -0.03
# multicollinearity 3                0.05             0.00        0.02
# class                              0.04            -0.00        0.01
#
#                        informative_2  multicollinearity 4  uniform corr 2  \
# code                           -0.02                -0.04            0.04
# correlated w target 1           0.47                 0.01            0.33
# uniform corr 1                  0.69                 0.01            0.46
# standard scaling                0.03                 0.06            0.03
# min max scaling                 0.01                 0.02            0.02
# outliers 1                      0.02                 0.02           -0.00
# informative_2                   1.00                -0.03            0.69
# multicollinearity 4            -0.03                 1.00            0.00
# uniform corr 2                  0.69                 0.00            1.00
# correlated w target 2           0.69                -0.01            0.54
# multicollinearity 2             0.04                 0.01            0.04
# duplicate_2                     1.00                -0.03            0.69
# target                          0.99                -0.02            0.70
# informative_1                   0.10                -0.02            0.02
# multicollinearity 1             0.07                -0.06            0.09
# duplicate_1                     0.10                -0.02            0.02
# outliers 2                     -0.03                 0.08           -0.00
# corr_feature_class              0.31                -0.02            0.21
# multicollinearity 3            -0.03                 0.90           -0.04
# class                           0.72                -0.05            0.52
#
#                        correlated w target 2  multicollinearity 2  \
# code                                   -0.00                -0.07
# correlated w target 1                   0.32                 0.06
# uniform corr 1                          0.53                 0.02
# standard scaling                        0.04                 0.04
# min max scaling                         0.03                 0.06
# outliers 1                             -0.01                -0.05
# informative_2                           0.69                 0.04
# multicollinearity 4                    -0.01                 0.01
# uniform corr 2                          0.54                 0.04
# correlated w target 2                   1.00                 0.06
# multicollinearity 2                     0.06                 1.00
# duplicate_2                             0.69                 0.04
# target                                  0.70                 0.04
# informative_1                          -0.03                 0.03
# multicollinearity 1                     0.08                 0.71
# duplicate_1                            -0.03                 0.03
# outliers 2                             -0.05                -0.01
# corr_feature_class                      0.20                 0.02
# multicollinearity 3                    -0.01                 0.02
# class                                   0.49                 0.03
#
#                        duplicate_2  target  informative_1  \
# code                         -0.02   -0.02           0.02
# correlated w target 1         0.47    0.47          -0.05
# uniform corr 1                0.69    0.70          -0.03
# standard scaling              0.03    0.03           0.01
# min max scaling               0.01    0.01          -0.01
# outliers 1                    0.02    0.02           0.03
# informative_2                 1.00    0.99           0.10
# multicollinearity 4          -0.03   -0.02          -0.02
# uniform corr 2                0.69    0.70           0.02
# correlated w target 2         0.69    0.70          -0.03
# multicollinearity 2           0.04    0.04           0.03
# duplicate_2                   1.00    0.99           0.10
# target                        0.99    1.00          -0.03
# informative_1                 0.10   -0.03           1.00
# multicollinearity 1           0.07    0.07           0.02
# duplicate_1                   0.10   -0.03           1.00
# outliers 2                   -0.03   -0.04           0.06
# corr_feature_class            0.31    0.32          -0.08
# multicollinearity 3          -0.03   -0.03          -0.03
# class                         0.72    0.72          -0.01
#
#                        multicollinearity 1  duplicate_1  outliers 2  \
# code                                 -0.04         0.02        0.06
# correlated w target 1                -0.01        -0.05       -0.03
# uniform corr 1                        0.00        -0.03       -0.01
# standard scaling                     -0.04         0.01       -0.02
# min max scaling                       0.01        -0.01       -0.03
# outliers 1                           -0.10         0.03        0.02
# informative_2                         0.07         0.10       -0.03
# multicollinearity 4                  -0.06        -0.02        0.08
# uniform corr 2                        0.09         0.02       -0.00
# correlated w target 2                 0.08        -0.03       -0.05
# multicollinearity 2                   0.71         0.03       -0.01
# duplicate_2                           0.07         0.10       -0.03
# target                                0.07        -0.03       -0.04
# informative_1                         0.02         1.00        0.06
# multicollinearity 1                   1.00         0.02       -0.01
# duplicate_1                           0.02         1.00        0.06
# outliers 2                           -0.01         0.06        1.00
# corr_feature_class                    0.08        -0.08        0.02
# multicollinearity 3                  -0.04        -0.03        0.05
# class                                 0.06        -0.01        0.01
#
#                        corr_feature_class  multicollinearity 3  class
# code                                -0.03                -0.06  -0.03
# correlated w target 1                0.14                 0.00   0.33
# uniform corr 1                       0.23                -0.02   0.55
# standard scaling                     0.01                 0.05   0.04
# min max scaling                      0.01                 0.00  -0.00
# outliers 1                          -0.03                 0.02   0.01
# informative_2                        0.31                -0.03   0.72
# multicollinearity 4                 -0.02                 0.90  -0.05
# uniform corr 2                       0.21                -0.04   0.52
# correlated w target 2                0.20                -0.01   0.49
# multicollinearity 2                  0.02                 0.02   0.03
# duplicate_2                          0.31                -0.03   0.72
# target                               0.32                -0.03   0.72
# informative_1                       -0.08                -0.03  -0.01
# multicollinearity 1                  0.08                -0.04   0.06
# duplicate_1                         -0.08                -0.03  -0.01
# outliers 2                           0.02                 0.05   0.01
# corr_feature_class                   1.00                -0.01   0.43
# multicollinearity 3                 -0.01                 1.00  -0.04
# class                                0.43                -0.04   1.00

# %%
# show correlation between the features
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# correlation matrix
sns.set(style="white")

# compute the correlation matrix
corr = df[df_numerical].corr().round(1)

# generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# set up the matplotlib figure
# f, ax = plt.subplots()
f = plt.figure(figsize=(12, 12))

# generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True);

plt.tight_layout()

# %%
# calculate the correlation matrix
corr_matrix = df[df_numerical].corr()

# Create a mask for the upper triangle (to avoid duplicates)
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

# Convert the correlation matrix to a long format
corr_df = corr_matrix.stack().reset_index()
corr_df.columns = ['feature1', 'feature2', 'correlation']

# Filter for correlations above a certain threshold (e.g., 0.7)
high_corr_df = corr_df[(abs(corr_df['correlation']) > 0.7) & (corr_df['feature1'] != corr_df['feature2'])]

# Sort by absolute correlation in descending order
high_corr_df = high_corr_df.sort_values(by='correlation', ascending=False, key=abs)

# Print the top correlated features
# print(high_corr_df['feature1'].to_list()[4:10])
print(high_corr_df)

# Create a variable to pickle
data = {'correlation scores': high_corr_df}

# %%
# check for vif
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor

# handle null values (using mean imputation for simplicity)
x_copy = df.drop('class', axis=1)._get_numeric_data()
x_copy.fillna(x_copy.mean(), inplace=True)

print(max([variance_inflation_factor(x_copy, i) for i in range(x_copy.shape[1])]))

# calculate VIF
vif = pd.DataFrame()
vif["Variable"] = x_copy.columns
vif["VIF"] = [variance_inflation_factor(x_copy, i) for i in range(x_copy.shape[1])]
print(vif)

# %% [markdown]
# ## Multicollinearity
#
# * We want high correlation with target
# * We don't want high correlation between features
# * Drop correlated features
# * Combine correlated features

# %%
# iterate dropping features with high vif
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor

removed=[]
x_copy1 = x_copy.copy()
max_vif = thresh = 10
while max_vif >= thresh:
  my_list = [variance_inflation_factor(x_copy1, i) for i in range(x_copy1.shape[1])]
  max_vif = max(my_list)
  if max_vif > thresh:
    max_index = my_list.index(max_vif)
    removed.append(x_copy1.columns[max_index])
    print(x_copy1.columns[max_index], variance_inflation_factor(x_copy1, max_index))
    x_copy1.drop(x_copy1.columns[max_index], axis=1, inplace=True)


# Calculate VIF
vif = pd.DataFrame()
vif["Variable"] = x_copy1.columns
vif["VIF"] = [variance_inflation_factor(x_copy1, i) for i in range(x_copy1.shape[1])]
print(vif)

# Create a variable to pickle
data = {'vif': vif}

# %%
print(removed)
# Out:
# ['informative_2', 'informative_1', 'target', 'standard scaling']

# %% [markdown]
# ## Outliers

# %%
# code along
df.boxplot(column=['outliers 1']);

# %%
# code along
df.describe()
# Out:
#                code  correlated w target 1  uniform corr 1  standard scaling  \
# count    706.000000             958.000000      907.000000        808.000000
# mean   49084.723796               0.164987        0.487087      50325.433201
# std    29207.819573               2.858401        0.291055       9530.459469
# min      516.000000              -7.154868        0.002158      22039.125947
# 25%    23031.750000              -1.733835        0.230461      44205.539616
# 50%    49989.500000               0.285805        0.478295      50127.897003
# 75%    74036.000000               2.063649        0.755199      56353.573271
# max    99871.000000              10.553648        0.998982      79738.399451
#
#        min max scaling  outliers 1  informative_2  multicollinearity 4  \
# count       810.000000  810.000000    1010.000000           506.000000
# mean        340.201698    0.005467      -0.018978             0.083047
# std          99.328141    1.392151       1.403413             0.961671
# min          17.200484   -5.840476      -4.543441            -2.977910
# 25%         276.702544   -0.725184      -1.050339            -0.564635
# 50%         341.523776   -0.049456      -0.194004             0.061666
# 75%         401.947667    0.724241       0.991017             0.769214
# max         694.928820    4.934702       4.020262             2.527816
#
#        uniform corr 2  correlated w target 2  multicollinearity 2  \
# count      810.000000             807.000000           908.000000
# mean         0.509498               0.202604            -0.001743
# std          0.288793               3.125033             1.050891
# min          0.002047              -9.934808            -2.845947
# 25%          0.251929              -1.853427            -0.702439
# 50%          0.517832               0.167358            -0.024862
# 75%          0.756875               2.226185             0.679778
# max          0.999535               8.918652             3.952274
#
#        duplicate_2       target  informative_1  multicollinearity 1  \
# count  1010.000000  1010.000000    1010.000000           508.000000
# mean     -0.018978     0.195609      -0.047372            -0.019113
# std       1.403413     2.991347       1.324010             1.053619
# min      -4.543441    -8.943212      -3.836929            -3.646075
# 25%      -1.050339    -2.166961      -1.018399            -0.775664
# 50%      -0.194004    -0.011259      -0.224366             0.017357
# 75%       0.991017     2.367192       0.975364             0.703397
# max       4.020262     9.299296       3.994644             3.734260
#
#        duplicate_1  outliers 2  corr_feature_class  multicollinearity 3  \
# count  1010.000000  709.000000          959.000000          1010.000000
# mean     -0.047372    3.068267            1.960921             0.032917
# std       1.324010    2.138054            3.053716             0.978972
# min      -3.836929   -4.010956          -12.097607            -3.563053
# 25%      -1.018399    1.655670            0.250316            -0.626606
# 50%      -0.224366    3.096026            1.980168             0.021031
# 75%       0.975364    4.438168            3.606005             0.723423
# max       3.994644    9.856741           12.695548             3.072818
#
#              class
# count  1010.000000
# mean      0.502970
# std       0.500239
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
import pandas as pd

def count_outliers_iqr(df, column):
    """Counts the number of outliers in a DataFrame column using the IQR method."""
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return len(outliers)

def detect_and_print_numerical_outliers_iqr(df):
    """
    Iterates through numerical columns in a DataFrame and prints the
    variable name with the number of outliers based on the IQR method.
    """
    numerical_cols = df.select_dtypes(include=['number']).columns
    for col in numerical_cols:
        num_outliers = count_outliers_iqr(df, col)
        print(f"Variable: {col}, Number of outliers (IQR): {num_outliers}")


detect_and_print_numerical_outliers_iqr(df[df_numerical])

# %%
df.to_csv('data science fiction iii pt 2.csv', index=False)

# %% [markdown]
# # Part 3 - Data Prep
#
# https://www.udemy.com/course/feature-engineering-for-machine-learning
#
# * Types and characteristics of data
# * Missing data imputation
# * Categorical encoding
# * Variable transformation
# * Discretization
# * Outliers
# * Datetime
# * Scaling
# * Feature creation

# %% [markdown]
# ## Load Data

# %%
import pandas as pd

df = pd.read_csv('data science fiction iii pt 2.csv')
print(df.shape)
print(df.info())
df.head()

# %% [markdown]
# ## Clean the Data

# %%
# constants

# %%
# quasi constants

# %%
# duplicate rows

# %%
# duplicate features

# %%
# missing data

# %%
# scaling

# %%
# outliers

# %% [markdown]
# ## Identify Variable Types for Encoding

# %%
# df_numerical = df.select_dtypes(include='number').columns
# df_object = df.select_dtypes(include=['object']).columns
# df_discreet = df.select_dtypes(include=['category']).columns
# df_categorical_features = df.select_dtypes(include=['category', 'object']).columns
# print(df_numerical)
# print(df_object)
# print(df_discreet)
# print(df_categorical_features)

# %% [markdown]
# # Part 4 - Feature Engineering

# %% [markdown]
# ## Derived Variables

# %%
# derived variables coding

# %% [markdown]
# ## Categorical Encoding

# %%
# categorical encoding

# %%
# check that everything is numerical

# %%
# df.to_csv('data science fiction iii pt 3.csv', index=False)

# %% [markdown]
# # Part 5 - Feature Selection
#
# * **The Signal:** This is the meaningful pattern in your data—the "truth" you want your model to learn.
# * **The Noise:** This is the random interference or irrelevant data that makes a model irrevelant or noisy.
# * **The Importance of Selection:** If you feed a model too much **noise** (irrelevant features), it might mistake a random coincidence for a rule. This is called "overfitting."
#
#
# ### 1. Filter Methods
# These are the fastest and simplest techniques. They act as a "pre-filter" by evaluating the statistical relationship between each feature and the target variable *before* any training happens. They don't care about which model you use later; they just look at the raw data.
# * **How they work:** They calculate a score (like Correlation) for each feature. If a feature's score is too low (it's mostly "noise"), it is dropped.
# * **Examples:** Correlation, VIF
#
# ### 2. Wrapper Methods
# These are more "hands-on" and computationally expensive. They treat the selection process as a search problem, using a specific machine learning model as a "judge" to see which combination of features performs best.
# * **How they work:** They train the model multiple times on different subsets of features and keep the group that yields the highest accuracy.
# * **Examples:** **Stepwise Selection**
#
# ### 3. Embedded Methods
# These methods are the most efficient because the selection happens *during* the training process. The model learns which features are important as it is being built.
# * **How they work:** The algorithm includes a penalty or a built-in logic that automatically shrinks the influence of useless features to zero.
# * **Examples:** **Random Forest Importance** or **LASSO Regression**.
#
# ### Summary Table
#
# | Method | Computational Cost | Risk of Overfitting | Metric Used |
# | :--- | :--- | :--- | :--- |
# | **Filter** | Low (Fastest) | Low | Statistical (e.g., $Chi^2$, Correlation) |
# | **Wrapper** | High (Slowest) | High | Model Performance (e.g., Accuracy, R2) |
# | **Embedded** | Medium | Medium | Internal Model Logic (e.g., Weights, Gini) |

# %%
# # get data
# import pandas as pd

# df = pd.read_csv('data science fiction iii pt 3.csv')
# print(df.shape)
# print(df.info())
# df.head()

# %% [markdown]
# ## Train Test Split
#
# random_state was initialized in the first code cell

# %%
# from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(df.drop('class', axis=1), df['class'], test_size=0.3, random_state=random_state)
# X_train.shape, X_test.shape

# %% [markdown]
# ## Mutual Information

# %%
# # mutual information
# import matplotlib.pyplot as plt
# from sklearn.feature_selection import mutual_info_classif

# mi = mutual_info_classif(X_train, y_train)
# mi = pd.Series(mi)
# mi.index = X_train.columns
# mi.sort_values(ascending=False).plot.bar()
# plt.ylabel('Mutual Information');

# %%
# mi_keepers = mi.sort_values(ascending=False).index[:5]
# print(mi_keepers)

# %% [markdown]
# ## SelectKBest

# %%
# # SelectKBest
# from sklearn.feature_selection import SelectKBest, f_regression, f_classif

# selector = SelectKBest(f_classif, k=5) # Select the top 5 features
# X_new = selector.fit(X_train, y_train)

# kb_keepers = X_train.columns.values[selector.get_support()]
# print(kb_keepers)

# %% [markdown]
# ## Select From Model

# %%
# # Select from model
# import numpy as np
# from sklearn.linear_model import LinearRegression, LogisticRegression
# from sklearn.feature_selection import SelectFromModel
# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler()
# scaler.fit(X_train)
# X_scaled = scaler.transform(X_train)

# selections = SelectFromModel(estimator=LogisticRegression()).fit(X_scaled, y_train)
# mt_keepers = X_train.columns.values[selections.get_support()]
# print(mt_keepers)

# %% [markdown]
# ## Recursive Feature Elmination

# %%
# from sklearn.feature_selection import RFE
# from sklearn.linear_model import LinearRegression, LogisticRegression

# estimator = LogisticRegression()
# selector = RFE(estimator, n_features_to_select=5) # Select the top 5 features
# X_new = selector.fit_transform(X_scaled, y_train)
# rf_keepers = X_train.columns.values[selections.get_support()]
# print(rf_keepers)

# %% [markdown]
# ## Random Forest Importance

# %%
# # random forest importance
# from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
# from sklearn.feature_selection import SelectFromModel

# selects = SelectFromModel(RandomForestClassifier(n_estimators=100, random_state=random_state), max_features=4)
# selects.fit(X_train, y_train)
# rfi = X_train.columns[(selects.get_support())]
# rfi.tolist()

# %% [markdown]
# ## Review Previous Variables
#
# * Correlated features
# * VIF
# * Outliers

# %%
# # make a list of features you have selected and use it as a filter
# features_to_model = []

# %%
# X_train = X_train[features_to_model]
# X_test = X_test[features_to_model]

# %% [markdown]
# # Part 6 - Data Modeling and Evaluation

# %% [markdown]
# ## Logistic Regression

# %%
# # model, predict, evaluate, and plot
# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import confusion_matrix, accuracy_score

# model = LogisticRegression(solver='liblinear', random_state=random_state)
# model.fit(X_train, y_train)
# predictions = model.predict(X_test)

# train_accuracy = model.score(X_train, y_train)
# print(f"Training Accuracy: {train_accuracy:.4f}")
# test_accuracy = model.score(X_test, y_test)
# print(f"Testing Accuracy: {test_accuracy:.4f}")

# %% [markdown]
# ## Model Evaluation

# %%
# from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# tn, fp, fn, tp = confusion_matrix(y_test, predictions).ravel()
# print('accuracy:', accuracy_score(y_test, predictions))
# # compare with other metrics

# %% [markdown]
# **The order of `y_test` (true labels) and `predictions` (predicted labels) matters significantly for `confusion_matrix` and `classification_report` in scikit-learn.**
#
# However, for **`accuracy_score`**, the order does **not** matter because it simply calculates the proportion of correctly classified instances, regardless of which is considered the "true" and which is the "predicted" set in the function call.
#
# Let's break down why the order is crucial for `confusion_matrix` and `classification_report`:
#
# **1. `confusion_matrix(y_test, predictions)`:**
#
# * The first argument (`y_test`) should always be the **true labels** (the actual values).
# * The second argument (`predictions`) should always be the **predicted labels** (the values your model has outputted).
#
# The output of `confusion_matrix` is a 2x2 (for binary classification) or NxN (for multi-class classification) array where:
#
# * The rows correspond to the **true classes**.
# * The columns correspond to the **predicted classes**.
#
# Therefore, `confusion_matrix(y_test, predictions)` will produce a matrix where:
#
# * `TN` (True Negative) is the count of instances where the true label was negative and the prediction was negative.
# * `FP` (False Positive) is the count of instances where the true label was negative and the prediction was positive.
# * `FN` (False Negative) is the count of instances where the true label was positive and the prediction was negative.
# * `TP` (True Positive) is the count of instances where the true label was positive and the prediction was positive.
#
# If you reverse the order and do `confusion_matrix(predictions, y_test)`, the rows and columns would effectively be swapped in terms of what they represent (true vs. predicted), leading to an incorrect interpretation of `TN`, `FP`, `FN`, and `TP`.
#
# **2. `classification_report(y_test, predictions)`:**
#
# * Similar to `confusion_matrix`, the first argument (`y_test`) must be the **true labels**, and the second argument (`predictions`) must be the **predicted labels**.
#
# The `classification_report` provides a text summary of the precision, recall, F1-score, and support for each class. These metrics are calculated based on the true positives, true negatives, false positives, and false negatives, which are directly derived from the correct alignment of true and predicted labels. Swapping the order would lead to incorrect calculations of these metrics for each class.
#
# **3. `accuracy_score(y_test, predictions)`:**
#
# * For `accuracy_score`, the order does **not** matter. Accuracy is calculated as the number of correct predictions divided by the total number of predictions:
#
#     `Accuracy = (Number of Correct Predictions) / (Total Number of Predictions)`
#
#     Whether you compare `y_test` against `predictions` or `predictions` against `y_test`, the set of correctly matched instances will be the same, and the total number of instances remains the same. Therefore, the accuracy score will be identical regardless of the order of the arguments.
#
# **In summary:**
#
# * **`confusion_matrix`:** **Order matters.** Always use `confusion_matrix(y_test, predictions)`.
# * **`classification_report`:** **Order matters.** Always use `classification_report(y_test, predictions)`.
# * **`accuracy_score`:** **Order does not matter.** `accuracy_score(y_test, predictions)` will yield the same result as `accuracy_score(predictions, y_test)`.
#
# It's crucial to maintain the correct order of true labels and predicted labels when using `confusion_matrix` and `classification_report` to ensure accurate evaluation of your classification model.

# %% [markdown]
# ## Metrics
#
# * tn = pred 0 actual 0
# * fp = pred 1 actual 0
# * fn = pred 0 actual 1
# * tp = pred 1 actual 1
# * acc(uracy) = $\frac{tn + tp}{total}$
# * error = $\frac{fp + fn}{total}$
# * prev(alence) = $\frac{fn + tp}{total}$
# * queue = $\frac{fp + tp}{total}$
# * tpr = $\frac{tp}{tp + fn}$
#     * true positive rate
#     * recall
#     * sensitivity
#     * prob of detection
#     * 1 - fnr
# * fnr = $\frac{fn}{tp + fn}$
#     * false negative rate
#     * type II error
#     * 1 - tpr
# * tnr = $\frac{tn}{tn + fp}$
#     * true negative rate
#     * specificity
#     * 1 - fpr
# * fpr = $\frac{fp}{tn + fp}$
#     * false positive rate
#     * type I error
#     * fall out
#     * prob of false claim
#     * 1 - tnr
# * ppv = $\frac{tp}{tp + fp}$
#     * positive predicted value
#     * precision
#     * 1 - fdr
# * fdr = $\frac{fp}{tp + fp}$
#     * false discovery rate
#     * 1 - ppv
# * npv = $\frac{tn}{tn + fn}$
#     * negative predicted value
#     * 1 - for
# * for = $\frac{fn}{tn + fn}$
#     * false omission rate
#     * 1 - npv
# * liklihood ratio+ (lr+) = $\frac{tpr}{fpr}$
#     * roc
# * liklihood ratio- (lr-) = $\frac{fnr}{tnr}$
# * diagnostic odds ratio = $\frac{lr+}{lr-}$
# * f1 score = 2 * $\frac{precision-recall}{precision+recall}$
# * Youden's J = sensitivity + specificity - 1 = tpr - fpr
# * Matthew's Correlation Coefficient = $\frac{(tp*tn)-(fp*tp)}{\sqrt{(tp+fp)(tp+fn)(tn+fp)(tn+fn)}}$

# %% [markdown]
# ## Confusion Matrix

# %%
# print(confusion_matrix(y_test, predictions))

# %% [markdown]
# ### Explanation
#
# Please explain what the Confusion Matrix is telling you

# %% [markdown]
# ## Precision Recall

# %%
# print(classification_report(y_test, predictions))

# %% [markdown]
# ### Explanation
#
# Please explain what precision and recall are telling you in the classification report

# %% [markdown]
# ## Bias Variance

# %%
# from mlxtend.evaluate import bias_variance_decomp

# avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(
#     model,
#     X_train.values, # Convert X_train to NumPy array
#     y_train.values, # Convert y_train to NumPy array
#     X_test.values, # Convert X_test to NumPy array
#     y_test.values, # Convert y_test to NumPy array
#     loss='0-1_loss',
#     random_seed=random_state)

# print('Average expected loss: %.3f' % avg_expected_loss)
# print('Average bias: %.3f' % avg_bias)
# print('Average variance: %.3f' % avg_var)

# %% [markdown]
# ### Explanation
#
# Please explain how to interpret bias variance and what it means to your model
